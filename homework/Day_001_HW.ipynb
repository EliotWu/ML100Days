# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    mse = sum((y - yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 211.475
# The Mean absolute error is 11.435

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 1. 你選的這組資料為何重要
# 我選的是關於新型冠狀病毒的資料(COVID-19 Open Research Dataset Challenge)連結如下：
# https://www.kaggle.com/allen-institute-for-ai/CORD-19-research-challenge
# 如果能利用AI、text mining萃取出有用的資訊，可以幫助我們了解病毒的起源、成因等，有助於人類對疫情的了解。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# AI2、Chan Zuckerberg Initiative、CSET、Microsoft Research、IBM、以及NLM底下的National Institutes of Health協同白宮科技政策辦公室製作的資料集。
# 3. 蒐集而來的資料型態為何
# 裏頭包含192,000篇學術文章(可能有圖表、文字、數字等)，其中有84,000個檔案是全文字檔。
# 4. 這組資料想解決的問題如何評估
# 問題包含「病毒的起源、傳染以及在環境裡的穩定性？」等17個需要解決的問題連結如下：
# https://www.kaggle.com/allen-institute-for-ai/CORD-19-research-challenge/tasks
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 要讓利潤上升有兩個方法1.增加收入2.降低成本，而自由載客車隊顯然必須把目標放在「如何增加載客數？」或是「如何增加每趟距離？」
# 然而，我們無法幫乘客決定距離，因此我們這邊假設距離是常態分配，把目標放在「如何增加載客數？」，另外以「月平均載客數」為衡量業績是否有提升的指標。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# 資料的收集可以透過1.過去乘客的搭乘紀錄2.自現在開始蒐集搭乘起點、搭乘目的地、搭乘距離、性別、職業、年齡等。
# 用這些資料分析出每個區域的目標客群，針對目標客群制定不同的行銷方式或營運策略，誘使他們選擇搭乘我們的載客車隊。
# 例如：如果我們分析出在機場平均每五分鐘會有一位客人搭車，相反在郊區平均每半小時有一位乘客搭車，那我們就在機場附近派駐較多的車子。
# 3. 蒐集而來的資料型態為何
# 有數值資料(如：搭乘距離、年齡)，也有類別資料(例如：起點、目的地、職業、性別等)
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 將調整過後的營運策略或行銷方式所得的「月平均載客數」與調整前的「月平均載客數」相比，判斷是否有顯著的差異。
